# %%
import edu1sces

# %%
N = 30
hm = edu1sces.model.HeisenbergModel(
    spins={i: 1.0 for i in range(N)},
    exchange_xy={(i, j): 1.0 for i in range(N) for j in range(N) if abs(i - j) == 1},
)

# %%
hm.calc_dim_u1_sector(0.5)
# Out:
# 0
